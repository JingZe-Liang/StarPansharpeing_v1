# %%
import matplotlib.pyplot as plt
import torch

# %%
bs = 10000
x = torch.randn(bs)
t = x.sigmoid()
plt_ts = torch.stack([x, t], dim=-1)

# bin plot
plt.hist(t, bins=100)
# Out:
# (array([  3.,   4.,  12.,  16.,  28.,  17.,  29.,  37.,  47.,  49.,  67.,
#          59.,  58.,  67.,  78.,  69.,  94., 102.,  96., 105.,  91., 118.,
#         104., 100., 108., 139., 129., 122., 134., 126., 140., 131., 143.,
#         145., 155., 148., 123., 156., 157., 161., 170., 178., 159., 149.,
#         173., 145., 151., 169., 140., 126., 162., 151., 167., 136., 136.,
#         133., 135., 152., 161., 145., 132., 138., 139., 149., 128., 156.,
#         132., 148., 123., 128., 133., 118., 108., 129., 100., 118., 108.,
#          98.,  94.,  87.,  96.,  95.,  72.,  72.,  90.,  70.,  54.,  52.,
#          51.,  30.,  42.,  34.,  21.,  17.,   8.,  12.,   6.,   4.,   1.,
#           2.]),
#  array([0.02517482, 0.03484946, 0.04452411, 0.05419876, 0.06387341,
#         0.07354806, 0.0832227 , 0.09289736, 0.10257201, 0.11224665,
#         0.1219213 , 0.13159595, 0.14127059, 0.15094525, 0.1606199 ,
#         0.17029454, 0.17996919, 0.18964384, 0.19931848, 0.20899314,
# ...
